# %% [markdown]
# # HW

# %% [raw]
# Мои Фамилия Имя: Кореков Егор

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# ##### Загрузите датасет titanic.csv

# %%
df_titanic = pd.read_csv('titanic.csv')

# %%
df_titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df_titanic.shape
# Out:
# (891, 12)

# %%
df_titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.6+ KB

# %% [markdown]
# > Обратите внимание на разное количество значений переменных
# Если это так - то у вас пропуски в данных. Такое бывает.
# Например в этом датасете не получилось выяснить всех подробностей у некоторых людей в виду утери данных, невозможности узнать или восстановить их

# %%
df_titanic.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# > Давайте возьмем для начала только несколько признаков, позже - вы увеличите их количество и сделаете соответствующую обработку.

# %%
columns = ['Sex', 'Age', 'Pclass', 'Survived']

# %%
simple_train = df_titanic[columns].loc[:500]
simple_test = df_titanic[columns].loc[500:]

# %% [markdown]
# > мы пока не умеем на уровне алгоритма работать с пропущенными значениями.
# Представьте вам дают 5-мерный вектор у которого заполнены только три компоненты и другой такой же вектор но у него заполнены лишь две  компоненты.  Как померить их сходство????
#
# distance_between( [1,0,1, NaN, NaN], [NaN, 1, 1, NaN, NaN] )

# %% [markdown]
# > один из вариантов - заполнить какими то значениями - например если это возраст - то заполнить средним по датасету или нулем.
#
# >> на будущее - в sklearn есть такой модуль - http://scikit-learn.org/stable/modules/impute.html но сейчас можете заполнить пропуски средствами pandas - метод fillna()

# %% [markdown]
# ##### Заполните пропущенные значения чем нибудь

# %%
mean_age=df_titanic['Age'].mean()
df_titanic['Age']=df_titanic['Age'].fillna(value=mean_age)
simple_train = df_titanic[columns].loc[:500]
simple_test = df_titanic[columns].loc[500:]
# можно inplace делать такое, а можно переприсваивать.

# %% [markdown]
# > мы чемпионы. Но мы понимаем, что алгоритм у нас метрический - он не понимает как померить близость векторов в которых содержатся строки
#
# distance( [1,1,0,'мужик'], [1, 0, 1, 'принцесска'] )
#
# > поэтому давайте заведем признак is_man который будет принимать значение 0 или 1.

# %% [markdown]
# ##### Заведите бинарный признак отвечающий за пол. Строковый удалите
#
# хинт - есть метод apply()

# %%
def func1(x):
    if x=='female':
        return 0
    if x=='male':
        return 1
    if x != 'male' and x != 'female':
        return x
    
simple_train.Sex=simple_train.Sex.apply(func1)
simple_test.Sex=simple_test.Sex.apply(func1)

# %% [markdown]
# ##### Сформируйте трейн и тест выборку, где в X лежат признаки 'Sex', 'Age', 'Pclass', а в у - Survived
#
# Результат - numpy array
#
# hint - у pandas есть метод drop() и атрибут values; Пощупайте их

# %%
X_train = simple_train.drop(columns=['Survived']).values
X_test = simple_test.drop(columns=['Survived']).values
y_train = simple_train['Survived'].values
y_test = simple_test['Survived'].values

# %%
assert isinstance(X_train, np.ndarray)
assert isinstance(X_test, np.ndarray)
assert isinstance(y_train, np.ndarray)
assert isinstance(y_test, np.ndarray)

# %%
assert X_train.shape[0] == y_train.shape[0]
assert X_test.shape[0] == y_test.shape[0]

# %%
assert not np.any(np.isnan(X_train)), 'у вас в данных есть пропущенные значения. Заполните их или удалите'
assert not np.any(np.isnan(X_test)), 'у вас в данных есть пропущенные значения. Заполните их или удалите'

# %% [markdown]
# ##### Реализуйте KNN. Сами, как делали это на лекции.
#
# Можете улучшить его.
# (например использовать kd-tree для быстрого поиска ближайших соседей,
#  или обходить соседей и класть расстояния в мин-кучу - тогда вы быстрее будете набирать их, без сортировки.)

# %%
class KNN:
    """
    simple KNN classifier with O(n) complexity for memory,
    and O(n log n) complexity - for nn search.
    """
    
    def __init__(self, n):
        self.n = n
        
    def fit(self, X, y):
        self.X = X
        self.y = y
    
    def predict(self, X):
        y_hat = []
        assert len(X.shape) == 2
        for vls in X:
            d = 0
            for index, value in enumerate(vls):
                d += (self.X[:, index] - value)**2
            d=np.sqrt(d)
            idx = np.argsort(d) [:self.n]
            counts = np.bincount(self.y[idx])
            prediction = np.argmax(counts)
            y_hat.append(prediction)
        return np.array(y_hat)

# %%
knn = KNN(5)

knn.fit(X_train, y_train)
y_pred = knn.predict(X_test)

# %% [markdown]
# ##### посчитайте руками (не используя sklearn) качество вашего предсказания

# %%
acc = np.mean(y_pred == y_test)
print('доля правильных ответов:', acc)
# Out:
# доля правильных ответов: 0.7851662404092071

# %%
np.unique(y_pred)
# Out:
# array([0, 1], dtype=int64)

# %% [markdown]
# > Мы получили бейслайн решение. Оно должно давать скорр в районе 0.76

# %% [markdown]
# ____

# %%
### можете проверить себя

from sklearn.metrics import accuracy_score
print(accuracy_score(y_test, y_pred))
# Out:
# 0.7851662404092071

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

clf=KNeighborsClassifier(n_neighbors=5)
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)

np.unique(y_pred)

print(accuracy_score(y_test, y_pred))
# Out:
# 0.7698209718670077

# %% [markdown]
# ##### TODO продолжение домашки

# %% [raw]
# 1) Добавьте еще признаков. Как минимум хочется чтобы вы добавили в X такие признаки как Cabin, Fare и Embarked.
#
# 2) Предобработайте признаки для нашего алгоритма. Поминим - что он (метрический) основан на том, что мы будем считать расстояния.
# Для этого нужно подготовить данные соответственно - привести к одному масштабу и проч.
# (https://sebastianraschka.com/Articles/2014_about_feature_scaling.html#about-standardization)
#
# Когда мы делаем такие преобразования - хочется чтобы знания и любая статистика о тесте не проникали в обучение -
# иначе будет проблема data leakage, а она в свою очередь приведет к переобучению.
#
# Поэтому аккуратно делим на трейн-тест (можно на трейн-валидацию-тест) считаем статистики на обучающей части и применяем их к тестовой.
#
#
# 3) Дальше. Признаки с пропусками - вы знаете что делать. Нужно проявить фантазию и погуглить как их правильно заполнять.
#
# 4) Признаки бывают непрерывными и категориальными. К категориальным признакам можно отнести например строки, тип палубы и прочее.
# Как их предобрабатывать - зависит от алгоритма.
# Самый простой способ, что сделать с категориальными признаками - представить в виде dummy признаков - так называемый one hot encoding.
#
# 4) признак Cabin мб может помочь, но нужно проявить фантазию и вытащить что нибудь полезное.
# Например - вытащить оттуда тип палубы.
#
# 5) Попробуйте разбить данные на три части (трейн-валидацию-тест) и подобрать гиперпараметр - число ближайших соседей.
# Как вариант можно выбирать на валидации алгоритм который дал наилучший скорр, а затем посмотреть его качество на тесте.
#
# 6) советоваться друг с другом можно. Списывать нельзя. Читайте треды kaggle. Спрашивайте преподавателей! Запилите крутые фичи!

# %%
columns = ['Sex', 'Age', 'Pclass', 'Survived', 'Cabin', 'Fare', 'Embarked']

# %%
simple_train = df_titanic[columns].loc[:500]
simple_test = df_titanic[columns].loc[500:]

# %%
mean_age = df_titanic['Age'].mean()
df_titanic['Age'] = df_titanic['Age'].fillna(value=mean_age)
df_titanic['Cabin'] = df_titanic['Cabin'].fillna(value = 0)

# %%
def embarked(x):
    if x == 'S':
        return 1
    elif x == 'C':
        return 2
    elif x == 'Q':
        return 3
    else:
        return x

# %%
df_titanic.Embarked = df_titanic.Embarked.apply(embarked)
mean_embarked = df_titanic.Embarked.mean()
df_titanic['Embarked'] = df_titanic['Embarked'].fillna(value = mean_embarked)

# %%
simple_train = df_titanic[columns].loc[:500]
simple_test = df_titanic[columns].loc[500:]

# %%
simple_train
# Out:
#         Sex        Age  Pclass  Survived        Cabin      Fare  Embarked
# 0      male  22.000000       3         0            0    7.2500       1.0
# 1    female  38.000000       1         1          C85   71.2833       2.0
# 2    female  26.000000       3         1            0    7.9250       1.0
# 3    female  35.000000       1         1         C123   53.1000       1.0
# 4      male  35.000000       3         0            0    8.0500       1.0
# 5      male  29.699118       3         0            0    8.4583       3.0
# 6      male  54.000000       1         0          E46   51.8625       1.0
# 7      male   2.000000       3         0            0   21.0750       1.0
# 8    female  27.000000       3         1            0   11.1333       1.0
# 9    female  14.000000       2         1            0   30.0708       2.0
# 10   female   4.000000       3         1           G6   16.7000       1.0
# 11   female  58.000000       1         1         C103   26.5500       1.0
# 12     male  20.000000       3         0            0    8.0500       1.0
# 13     male  39.000000       3         0            0   31.2750       1.0
# 14   female  14.000000       3         0            0    7.8542       1.0
# 15   female  55.000000       2         1            0   16.0000       1.0
# 16     male   2.000000       3         0            0   29.1250       3.0
# 17     male  29.699118       2         1            0   13.0000       1.0
# 18   female  31.000000       3         0            0   18.0000       1.0
# 19   female  29.699118       3         1            0    7.2250       2.0
# 20     male  35.000000       2         0            0   26.0000       1.0
# 21     male  34.000000       2         1          D56   13.0000       1.0
# 22   female  15.000000       3         1            0    8.0292       3.0
# 23     male  28.000000       1         1           A6   35.5000       1.0
# 24   female   8.000000       3         0            0   21.0750       1.0
# 25   female  38.000000       3         1            0   31.3875       1.0
# 26     male  29.699118       3         0            0    7.2250       2.0
# 27     male  19.000000       1         0  C23 C25 C27  263.0000       1.0
# 28   female  29.699118       3         1            0    7.8792       3.0
# 29     male  29.699118       3         0            0    7.8958       1.0
# ..      ...        ...     ...       ...          ...       ...       ...
# 471    male  38.000000       3         0            0    8.6625       1.0
# 472  female  33.000000       2         1            0   27.7500       1.0
# 473  female  23.000000       2         1            D   13.7917       2.0
# 474  female  22.000000       3         0            0    9.8375       1.0
# 475    male  29.699118       1         0          A14   52.0000       1.0
# 476    male  34.000000       2         0            0   21.0000       1.0
# 477    male  29.000000       3         0            0    7.0458       1.0
# 478    male  22.000000       3         0            0    7.5208       1.0
# 479  female   2.000000       3         1            0   12.2875       1.0
# 480    male   9.000000       3         0            0   46.9000       1.0
# 481    male  29.699118       2         0            0    0.0000       1.0
# 482    male  50.000000       3         0            0    8.0500       1.0
# 483  female  63.000000       3         1            0    9.5875       1.0
# 484    male  25.000000       1         1          B49   91.0792       2.0
# 485  female  29.699118       3         0            0   25.4667       1.0
# 486  female  35.000000       1         1          C93   90.0000       1.0
# 487    male  58.000000       1         0          B37   29.7000       2.0
# 488    male  30.000000       3         0            0    8.0500       1.0
# 489    male   9.000000       3         1            0   15.9000       1.0
# 490    male  29.699118       3         0            0   19.9667       1.0
# 491    male  21.000000       3         0            0    7.2500       1.0
# 492    male  55.000000       1         0          C30   30.5000       1.0
# 493    male  71.000000       1         0            0   49.5042       2.0
# 494    male  21.000000       3         0            0    8.0500       1.0
# 495    male  29.699118       3         0            0   14.4583       2.0
# 496  female  54.000000       1         1          D20   78.2667       2.0
# 497    male  29.699118       3         0            0   15.1000       1.0
# 498  female  25.000000       1         0      C22 C26  151.5500       1.0
# 499    male  24.000000       3         0            0    7.7958       1.0
# 500    male  17.000000       3         0            0    8.6625       1.0
#
# [501 rows x 7 columns]

# %%
simple_train.Sex=simple_train.Sex.apply(func1)
simple_test.Sex=simple_test.Sex.apply(func1)

# %%
def cabin(x):
    if type(x) == str:
        return x[0]
    else:
        return x

# %%
simple_train.Cabin = simple_train.Cabin.apply(cabin)
simple_test.Cabin = simple_test.Cabin.apply(cabin)
simple_train[simple_train['Pclass'] == 3].Cabin.unique()
# Out:
# array([0, 'G', 'F', 'E'], dtype=object)

# %%
def cabin1(x):
    if x == 'A':
        return 1
    elif x == 'B':
        return 2
    elif x == 'C':
        return 3
    elif x == 'D':
        return 4
    elif x == 'E':
        return 5 
    elif x == 'F':
        return 6
    elif x == 'G':
        return 7
    elif x == 'T':
        return 0
    else:
        return x

# %%
simple_train.Cabin = simple_train.Cabin.apply(cabin1)
simple_test.Cabin = simple_test.Cabin.apply(cabin1)
simple_test
# Out:
#      Sex        Age  Pclass  Survived  Cabin      Fare  Embarked
# 500    1  17.000000       3         0      0    8.6625       1.0
# 501    0  21.000000       3         0      0    7.7500       3.0
# 502    0  29.699118       3         0      0    7.6292       3.0
# 503    0  37.000000       3         0      0    9.5875       1.0
# 504    0  16.000000       1         1      2   86.5000       1.0
# 505    1  18.000000       1         0      3  108.9000       2.0
# 506    0  33.000000       2         1      0   26.0000       1.0
# 507    1  29.699118       1         1      0   26.5500       1.0
# 508    1  28.000000       3         0      0   22.5250       1.0
# 509    1  26.000000       3         1      0   56.4958       1.0
# 510    1  29.000000       3         1      0    7.7500       3.0
# 511    1  29.699118       3         0      0    8.0500       1.0
# 512    1  36.000000       1         1      5   26.2875       1.0
# 513    0  54.000000       1         1      0   59.4000       2.0
# 514    1  24.000000       3         0      0    7.4958       1.0
# 515    1  47.000000       1         0      4   34.0208       1.0
# 516    0  34.000000       2         1      6   10.5000       1.0
# 517    1  29.699118       3         0      0   24.1500       3.0
# 518    0  36.000000       2         1      0   26.0000       1.0
# 519    1  32.000000       3         0      0    7.8958       1.0
# 520    0  30.000000       1         1      2   93.5000       1.0
# 521    1  22.000000       3         0      0    7.8958       1.0
# 522    1  29.699118       3         0      0    7.2250       2.0
# 523    0  44.000000       1         1      2   57.9792       2.0
# 524    1  29.699118       3         0      0    7.2292       2.0
# 525    1  40.500000       3         0      0    7.7500       3.0
# 526    0  50.000000       2         1      0   10.5000       1.0
# 527    1  29.699118       1         0      3  221.7792       1.0
# 528    1  39.000000       3         0      0    7.9250       1.0
# 529    1  23.000000       2         0      0   11.5000       1.0
# ..   ...        ...     ...       ...    ...       ...       ...
# 861    1  21.000000       2         0      0   11.5000       1.0
# 862    0  48.000000       1         1      4   25.9292       1.0
# 863    0  29.699118       3         0      0   69.5500       1.0
# 864    1  24.000000       2         0      0   13.0000       1.0
# 865    0  42.000000       2         1      0   13.0000       1.0
# 866    0  27.000000       2         1      0   13.8583       2.0
# 867    1  31.000000       1         0      1   50.4958       1.0
# 868    1  29.699118       3         0      0    9.5000       1.0
# 869    1   4.000000       3         1      0   11.1333       1.0
# 870    1  26.000000       3         0      0    7.8958       1.0
# 871    0  47.000000       1         1      4   52.5542       1.0
# 872    1  33.000000       1         0      2    5.0000       1.0
# 873    1  47.000000       3         0      0    9.0000       1.0
# 874    0  28.000000       2         1      0   24.0000       2.0
# 875    0  15.000000       3         1      0    7.2250       2.0
# 876    1  20.000000       3         0      0    9.8458       1.0
# 877    1  19.000000       3         0      0    7.8958       1.0
# 878    1  29.699118       3         0      0    7.8958       1.0
# 879    0  56.000000       1         1      3   83.1583       2.0
# 880    0  25.000000       2         1      0   26.0000       1.0
# 881    1  33.000000       3         0      0    7.8958       1.0
# 882    0  22.000000       3         0      0   10.5167       1.0
# 883    1  28.000000       2         0      0   10.5000       1.0
# 884    1  25.000000       3         0      0    7.0500       1.0
# 885    0  39.000000       3         0      0   29.1250       3.0
# 886    1  27.000000       2         0      0   13.0000       1.0
# 887    0  19.000000       1         1      2   30.0000       1.0
# 888    0  29.699118       3         0      0   23.4500       1.0
# 889    1  26.000000       1         1      3   30.0000       2.0
# 890    1  32.000000       3         0      0    7.7500       3.0
#
# [391 rows x 7 columns]

# %%
X_train = simple_train.drop(columns=['Survived']).values
X_test = simple_test.drop(columns=['Survived']).values
y_train = simple_train['Survived'].values
y_test = simple_test['Survived'].values

# %%
mean_ = X_train.mean(axis=0)
std_ = X_train.std(axis=0)

X_train = (X_train - mean_) / std_
X_test = (X_test - mean_) / std_

# %%
max_ = X_train.max(axis=0)
min_ = X_train.min(axis=0)

X_train = (X_train - min_) / (max_ - min_)
X_test = (X_test - min_) / (max_ - min_)

# %%
# Out:
# array([[1.        , 0.23131673, 1.        , 0.        , 0.01690807,
#         0.        ],
#        [0.        , 0.28825623, 1.        , 0.        , 0.01512699,
#         1.        ],
#        [0.        , 0.41208708, 1.        , 0.        , 0.01489121,
#         1.        ],
#        ...,
#        [0.        , 0.41208708, 1.        , 0.        , 0.04577135,
#         0.        ],
#        [1.        , 0.3594306 , 0.        , 0.42857143, 0.0585561 ,
#         0.5       ],
#        [1.        , 0.44483986, 1.        , 0.        , 0.01512699,
#         1.        ]])

# %%
knn = KNN(21)

knn.fit(X_train, y_train)
y_pred = knn.predict(X_test)

# %%
acc = np.mean(y_pred == y_test)
print('доля правильных ответов:', acc)
# Out:
# доля правильных ответов: 0.7928388746803069

# %%
def func2(x):
    knn=KNN(x)
    knn.fit(X_train, y_train)
    y_pred = knn.predict(X_test)
    acc = np.mean(y_pred == y_test)
    return acc

# %%
plt.plot([i for i in range(1, 80)], [func2(i) for i in range(1, 80)])
plt.ylabel('доля верных')
plt.xlabel('количество ближайших соседей')
# Out:
# Text(0.5,0,'количество соседей')

# %%
max_acc=0
n=0
for x in range(1,80):
    if func2(x)>max_acc:
        n=x
        max_acc=func2(x)

# %%
max_acc
# Out:
# 0.8107416879795396

# %%
n
# Out:
# 14
