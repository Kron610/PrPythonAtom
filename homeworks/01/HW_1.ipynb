# %%
class HashMap:
    
    class Entry:
        def __init__(self, key, value):
            #TODO store key and value as attributes
            self.key=key
            self.value=value
        def get_key(self):
            #TODO return key
            return self.key
        def get_value(self):
            #TODO return value
            return self.value
        def __eq__(self, other):
            #TODO реализовать функцию сравнения
            #Пояснения: self - текущий объект entry, other - какой-то другой объект
            #Какое условие на равенство объектов в ассоциативном массиве?
            #Если объекты равны, то метод должен возвращать True, иначе False
            return self.get_key()==other.get_key() 
    
    def __init__(self, bucket_num = 64):
        #TODO Создать массив для бакетов
        self.buckets=[None]*bucket_num

    def get(self, key, default_value=None):
        #TODO метод get, возвращающий значение, если оно присутствует, иначе default_value
        hash_key=self._get_index(self._get_hash(key))
        if self.buckets[hash_key] is not None:
            for i in self.buckets[hash_key]:
                if i.get_key()==key:
                    return i.get_value()
        return default_value

    def put(self, key, value):
        #TODO метод put, кладет значение по ключу, в случае, если ключ уже присутствует он его заменяет
        hash_key=self._get_index(self._get_hash(key))
        Note=self.Entry(key,value)
        if self.buckets[hash_key] is None:
            self.buckets[hash_key]=[Note]
            return True
        else:
            for i in range(0,len(self.buckets[hash_key]),1):
                if self.buckets[hash_key][i]==Note:
                    self.buckets[hash_key][i]=Note
                    return True
        self.buckets[hash_key].append(Note)
        return True

    def __len__(self):
        #TODO Возвращает количество Entry в массиве
        count=0
        for i in self.buckets:
            if i is not None:
                for j in i:
                    count+=1
        return count
    def _get_hash(self, key):
        #TODO Вернуть хеш от ключа, по которому он кладется в бакет
        hash_0=0
        for char in str(key):
            hash_0+=ord(char)
        return hash_0

    def _get_index(self, hash_value):
        #TODO По значению хеша вернуть индекс элемента в массиве
        return hash_value%len(self.buckets)
    def values(self):
        #TODO Задание со звездочкой!
        #Должен возвращать генератор или итератор значений (на самом деле итератор, но не принципиально, через генераторы проще ИМХО)
        return [j.get_value() for i in self.buckets if i is not None for j in i]
        
    def keys(self):
        #TODO Задание со звездочкой!
        #Должен возвращать генератор или итератор ключей (на самом деле итератор, но не принципиально, через генераторы проще ИМХО)
        return [j.get_key() for i in self.buckets if i is not None for j in i]
        
    def items(self):
        #TODO Задание со звездочкой!
        #Должен возвращать генератор или итератор пар ключ и значение (tuples)
        #(на самом деле итератор, но не принципиально, через генераторы проще ИМХО)
        return [(j.get_key(),j.get_value()) for i in self.buckets if i is not None for j in i ]
        
    def __str__(self):
        #TODO Метод, вызываемый при вызове print, пофантазируйте, что можно написать
        return str([(j.get_key(),j.get_value()) for i in self.buckets if i is not None for j in i ])

# %%
class HashSet(HashMap):
   
    def get(self, key, default_value=None):
        #TODO достаточно переопределить данный метод
        hash_key=self._get_index(self._get_hash(key))
        if self.buckets[hash_key] is not None:
            for i in self.buckets[hash_key]:
                if i.get_key()==key:
                    return i.get_key()
        return default_value

    def put(self, key, value='value'):
        #TODO метод put, нужно переопределить данный метод
        hash_key=self._get_index(self._get_hash(key))
        Note=self.Entry(key,value)
        if self.buckets[hash_key] is None:
            self.buckets[hash_key]=[Note]
            return True
        else:
            for i in range(0,len(self.buckets[hash_key]),1):
                if self.buckets[hash_key][i]==Note:
                    return True
        self.buckets[hash_key].append(Note)
        return True

 

    def values(self):
        #TODO Задание со звездочкой!
        #Если делали, то нужно бы переопределить
        #Должен возвращать генератор или итератор значений (на самом деле итератор, но не принципиально, через генераторы проще ИМХО)
        return [j.get_key() for i in self.buckets if i is not None for j in i]
